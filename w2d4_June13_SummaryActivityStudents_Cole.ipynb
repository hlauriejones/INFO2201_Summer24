# %% [markdown]
# # Week 2 Summary Activity

# %% [markdown]
# ## Problem 1 - Dictionaries

# %%
student_dictionary = { 101 : {'Name': 'George Bluth',
                              'AverageScore': 85,
                               'Year' : 2,
                              'Class' : 'INFO1201'
                              },
                        102 : {'Name': 'Lucille Bluth',
                              'AverageScore': 100,
                               'Year' : 3,
                              'Class' : 'INFO1201'
                              },
                     103 : {'Name': 'George Michael Bluth',
                              'AverageScore': 98,
                               'Year' : 1,
                              'Class' : 'INFO1101'
                              },
                     104 : {'Name': 'Michael Bluth',
                     
                              'AverageScore': 90,
                               'Year' : 5,
                              'Class' : 'INFO2201'
                              },
                     105 : {'Name': 'Gob Bluth',
                              'AverageScore': 40,
                               'Year' : 8,
                              'Class' : 'INFO1101'
                              },
                     106 : {'Name': 'Lindsay Bluth',
                              'AverageScore': 70,
                               'Year' : 4,
                              'Class' : 'INFO1201'
                              },
                     107 : {'Name': 'Buster Bluth',
                              'AverageScore': 95,
                               'Year' : 2,
                              'Class' : 'INFO1201'
                              },
                     108 : {'Name': 'Sally Sitwell',
                              'AverageScore': 93,
                               'Year' : 2,
                              'Class' : 'INFO1201'
                              }}

# %% [markdown]
# #### Question 1:
# Iterate through the dictionary and print out students names and their average score
# Ex: Lucille Bluth : 98

# %%
student_dictionary.keys()
# Out:
# dict_keys([101, 102, 103, 104, 105, 106, 107, 108])

# %%
ctr1=101
for stud in student_dictionary:
    print('Student Name -',student_dictionary[ctr1]['Name'],'Average Score -',student_dictionary[ctr1]['AverageScore'])
    ctr1+=1
# Out:
# Student Name - George Bluth Average Score - 85
# Student Name - Lucille Bluth Average Score - 100
# Student Name - George Michael Bluth Average Score - 98
# Student Name - Michael Bluth Average Score - 90
# Student Name - Gob Bluth Average Score - 40
# Student Name - Lindsay Bluth Average Score - 70
# Student Name - Buster Bluth Average Score - 95
# Student Name - Sally Sitwell Average Score - 93

# %% [markdown]
# #### Question 2:
# Find the student with the highest average score

# %%
highScore=0
ctr1=101

for stud in student_dictionary:
    tmpScore = student_dictionary[ctr1]['AverageScore']
    if tmpScore >=highScore:
        highScore = student_dictionary[ctr1]['AverageScore']
    ctr1+=1


print(highScore)
# Out:
# 100

# %% [markdown]
# #### Question 3:
# Find the total average of all the students

# %%
finalScore=0
ctr1=101
for stud in student_dictionary:
    tmpScore = student_dictionary[ctr1]['AverageScore']
    finalScore=finalScore+tmpScore
    ctr1+=1
print(finalScore/len(student_dictionary))
# Out:
# 83.875

# %% [markdown]
# ## Problem 2 - Functions

# %% [markdown]
# Make a computer-based doctor. This shoudl simulates a session of non-directive psychotherapy.
# The program (doctor) prints a greeting and waits for the user (patient) to answer an initial question.
#
# Each answer entered by the user results in a related reply by the program that continues the conversation.
#
# When the user enters 'quit,' the program signs off with a goodbye.
#
# Based upon the data (lists, dictionaries, and tuples) provided, make a 'reply' function that will randomly generate a number. Based upon that number have the 'doctor' say different outputs. You must be able to
# - use a hedge
# - have a phrase that says 'earlier you said that..' and refer to something already put in the input
#
# hint: random.choice() could help here

# %%
hedges = ('Please tell me more', 'Many of my patients tell me the same thing',
          'Please continue')

history = []

import random

# %%
def doctor():
    print('Welcome to the drs')
    print('How are you doing today on  a scale from 1-10')
    personFeel=input()
    if personFeel=='quit':
        return
    else:
        while personFeel < 0 or personFeel > 10:
            print('Invalid Input, please enter a number between 1-10')
             personFeel=input()
             if personFeel=='quit':
                  return
    history.append(personFeel)
    if personFeel > 7:
        print('Thats pretty good!' 'What isues are you having today?')
        feelingl2=input()
        history.append(feeling2)
    elif personFeel > 3:
        print('ooh' 'what can I help with')
        feelingl2=input()
        if feeling2=='quit':
            return
        history.append(feeling2)
    els:
        print('Thats pretty bad' 'what can I help with')
        feeling2=input()
        if feel=='quit':
            return
        history.append(feeling2)
# Out:
#   Cell In[53], line 10
#     personFeel=input()
#     ^
# IndentationError: unexpected indent

# %%
def doctor2():
    print('Welcome to the drs')
    print('How are you doing today on  a scale from 1-10')
    personFeel=input()
    if personFeel=='quit':
        return
    while personFeel < 0 or personFeel > 10:
        print('Invalid Input, please enter a number between 1-10')
        personFeel=input()
        if personFeel=='quit':
          return
    else:
        if personFeel > 7:
            print('Thats pretty good!' 'What isues are you having today?')
            feelingl2=input()
            if feeling2 not in history:
                history.append(feeling2)
            elif feeling2 in history:
                print('Did I just hear you say that ')
        elif personFeel > 3:
            print('ooh' 'what can I help with')
        feelingl2=input()
        if feeling2=='quit':
                return
        if feeling2 not in history:
                history.append(feeling2)
            elif feeling2 in history:
                print('Did I just hear you say that ')

# %% [markdown]
# ### Optional- to add complexity you can use qualifiers and replacements:
#
# Create a function called 'change person' that will change the sentence to include the right pronoun and responds with a qualifier + the sentence again.

# %%
replacements = {'i':'you', 'me':'you', 'my':'your',
                'we':'you', 'us':'you',  'you':"i"}

qualifiers = ['Why do you say that ', 'You seem to think that ',
              'Did I just hear you say that ']

# %%
answers = ['1test','233','333333']
answers[random.randint(0,2)]
# Out:
# '233'

# %% [markdown]
# ## Problem 3 - Classes

# %% [markdown]
# #### Question 1:
#
# Build a class object for restaurant informatoin. The class should have the following:
# 1.   A method that reads dishes and append them to a list or a dictionary
# 2.   A method that prints out the saved dishes

# %%
class Restaurant:
    def __init__(self,name):
        self.name=name
        self.listOfDishes=[]
    def saveDishes(self,listOfDishes):
        self.listOfDishes.append(listOfDishes)
    def readDishes(self):
        print(self.listOfDishes)

# %% [markdown]
# #### Question 2:
#
# create a class instance

# %%
r1=Restaurant('sink')
r1.saveDishes(['burger','fries','salad'])
r1.readDishes()

r1.name
# Out:
# [['burger', 'fries', 'salad']]
# 'sink'

# %% [markdown]
# #### Question 3:
# use the two methods you created

# %%
r1=Restaurant('sink')
r1.saveDishes(['burger','fries','salad'])
r1.readDishes()
# Out:
# [['burger', 'fries', 'salad']]

# %%
r1=Restaurant('sink')
r1.saveDishes(['burger','fries','salad'])
r1.readDishes()

r1.saveDishes('pizza')
# Out:
# [['burger', 'fries', 'salad']]

# %%
r1.saveDishes('water')
r1.readDishes()
# Out:
# [['burger', 'fries', 'salad'], 'pizza', 'water', 'water', 'water', 'water']

# %% [markdown]
# #### Question 4:
#
# update a value you have in the class instance you created

# %%
r1.name = 'The Corner'

# %%
r1.name
# Out:
# 'The Corner'
